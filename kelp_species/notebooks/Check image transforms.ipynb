# %%
import sys

sys.path.append("/home/taylor/PycharmProjects/uav-classif")

# %%
import matplotlib.pyplot as plt
import numpy as np

from utils.dataset.SegmentationDataset import SegmentationDataset
from utils.dataset.transforms import transforms as t

# %%
train_data = SegmentationDataset("/home/taylor/PycharmProjects/uav-classif/kelp_species/train_input/data/train",
                                transform=t.train_transforms, target_transform=t.train_target_transforms)

# %%
def show_x(X):
    _X = t.inv_normalize(X).numpy()
    _X = np.moveaxis(_X, 0, 2)

    plt.imshow(_X)
    plt.show()

for idx in range(10):
    X, y = train_data[idx]
    show_x(X)
